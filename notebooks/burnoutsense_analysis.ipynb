# %% [markdown]
# # BurnoutSense AI Analysis Notebook
#
# This notebook reproduces the end-to-end behavioral analytics workflow for employee burnout prediction and fatigue intelligence.

# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.pipeline import execute_pipeline, load_raw_data, clean_dataset
sns.set_theme(style='whitegrid')

# %%
raw_data = load_raw_data()
processed_data = clean_dataset(raw_data)
raw_data.head()

# %%
processed_data.groupby('burnout_risk')[['work_hours', 'sleep_hours', 'isolation_index', 'task_completion']].mean().round(2)

# %%
artifacts = execute_pipeline()
artifacts.metrics

# %% [markdown]
# ## Summary
#
# The pipeline writes all reports, metrics, trained artifacts, and visualizations to the repository folders after execution.
